# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
tw_50 = pd.read_csv('tw_50.csv')
tw_tech = pd.read_csv('tw_tech_100.csv')

# %%
tw_50['close'].plot()

# %%
tw_tech['close'].plot()
